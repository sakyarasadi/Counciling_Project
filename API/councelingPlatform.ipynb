# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python -m spacy info
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.7.5
# Location         /usr/local/lib/python3.10/dist-packages/spacy
# Platform         Linux-6.1.85+-x86_64-with-glibc2.35
# Python version   3.10.12
# Pipelines        en_core_web_sm (3.7.1)

# %%
 import spacy
 from spacy.tokens import DocBin
 from tqdm import tqdm

 nlp = spacy.blank("en") # load a new spacy model
 db = DocBin() # create a DocBin object

# %%
import json
f = open('/content/annotations.json')
TRAIN_DATA = json.load(f)

# %%
TRAIN_DATA
# Out:
# {'classes': ['ANXIETY_POSITIVE',
#   'SCHIZOPHRENIA_POSITIVE',
#   'DEPRESSION_POSITIVE',
#   'MANIA_POSITIVE',
#   'BIPOLARDISORDER_POSITIVE',
#   'STRESS_POSITIVE',
#   'ADDICTION_POSITIVE'],
#  'annotations': [["Yes, I've been feeling constantly nervous and worried about a lot of things, even Worry about small issues\r",
#    {'entities': [[23, 53, 'ANXIETY_POSITIVE'],
#      [82, 106, 'ANXIETY_POSITIVE']]}],
#   ["I feel anxious almost every day, even when there's no clear reason for it.\r",
#    {'entities': [[7, 31, 'ANXIETY_POSITIVE'], [51, 66, 'ANXIETY_POSITIVE']]}],
#   ["Honestly, it's been a rollercoaster of emotions.\r",
#    {'entities': [[22, 47, 'ANXIETY_POSITIVE']]}],
#   ["I've felt this undercurrent of worry for weeks now.\r",
#    {'entities': [[15, 36, 'ANXIETY_POSITIVE']]}],
#   ["It's like my mind racing all the time, jumping from one thing to the next.\r",
#    {'entities': [[13, 24, 'ANXIETY_POSITIVE']]}],
#   ['Simple tasks that used to be easy feel overwhelmed by simple tasks.\r',
#    {'entities': [[39, 66, 'ANXIETY_POSITIVE']]}],
#   ['I find myself getting easily irritated and snapping at people, which I hate doing.\r',
#    {'entities': [[22, 38, 'ANXIETY_POSITIVE']]}],
#   ["My sleep has been terrible – either I can't fall asleep, or I wake up constantly\r",
#    {'entities': [[3, 26, 'ANXIETY_POSITIVE']]}],
#   ["And don't even get me started on the physical symptoms – the heart palpitations, sweating, and that tight feeling in my chest.\r",
#    {'entities': [[67, 79, 'ANXIETY_POSITIVE'],
#      [81, 89, 'ANXIETY_POSITIVE'],
#      [100, 125, 'ANXIETY_POSITIVE']]}],
#   ["It's exhausting/ Exhaustion\r",
#    {'entities': [[17, 27, 'ANXIETY_POSITIVE']]}],
#   ["I know it's not normal, but I can't shake it off.\r",
#    {'entities': [[30, 48, 'ANXIETY_POSITIVE']]}],
#   ['Specific worries or fear\r', {'entities': [[0, 16, 'ANXIETY_POSITIVE']]}],
#   ['Panic attacks or intrusive thoughts \r',
#    {'entities': [[0, 13, 'ANXIETY_POSITIVE'], [17, 35, 'ANXIETY_POSITIVE']]}],
#   ['Avoiding social situations\r',
#    {'entities': [[0, 26, 'ANXIETY_POSITIVE']]}],
#   ['Difficulty concentrating\r', {'entities': [[0, 24, 'ANXIETY_POSITIVE']]}],
#   ["I'm experiencing feelings of panic and uneasiness today.\r",
#    {'entities': [[39, 49, 'ANXIETY_POSITIVE']]}],
#   ["It's been a challenging day,\r",
#    {'entities': [[12, 27, 'ANXIETY_POSITIVE']]}],
#   ["I've had trouble sleeping and my anxiety levels are through the roof.\r",
#    {'entities': [[9, 25, 'ANXIETY_POSITIVE'], [30, 40, 'ANXIETY_POSITIVE']]}],
#   ["I can't stay calm and still.\r",
#    {'entities': [[2, 17, 'ANXIETY_POSITIVE']]}],
#   ['My hands and feet are cold and sweaty.\r',
#    {'entities': [[22, 37, 'ANXIETY_POSITIVE']]}],
#   ["I'm breathing faster than usual, and my heart is racing.\r",
#    {'entities': [[40, 55, 'ANXIETY_POSITIVE']]}],
#   ["It's an anxious day for me.\r",
#    {'entities': [[8, 19, 'ANXIETY_POSITIVE']]}],
#   ['My mouth is dry, and I’m feeling nauseous/ Nausea\r',
#    {'entities': [[3, 15, 'ANXIETY_POSITIVE'], [25, 49, 'ANXIETY_POSITIVE']]}],
#   ['I think my anxiety is getting the best of me today.\r',
#    {'entities': [[11, 38, 'ANXIETY_POSITIVE']]}],
#   ['I’ve been ruminating on a problem endlessly.\r',
#    {'entities': [[10, 43, 'ANXIETY_POSITIVE']]}],
#   ['I just can’t concentrate on anything else.\r',
#    {'entities': [[7, 41, 'ANXIETY_POSITIVE']]}],
#   ['Avoiding feared places has been struggle today.\r',
#    {'entities': [[27, 40, 'ANXIETY_POSITIVE']]}],
#   ['My anxiety is quite intense.\r',
#    {'entities': [[0, 10, 'ANXIETY_POSITIVE'], [14, 27, 'ANXIETY_POSITIVE']]}],
#   ['I feel like my muscles are constantly tensed and dizziness has been bothering me.\r',
#    {'entities': [[27, 44, 'ANXIETY_POSITIVE'], [49, 81, 'ANXIETY_POSITIVE']]}],
#   ['My mind is racing negative thoughts.\r',
#    {'entities': [[11, 35, 'ANXIETY_POSITIVE']]}],
#   ['I can’t stop thinking about various worries and fears.\r',
#    {'entities': [[28, 53, 'ANXIETY_POSITIVE']]}],
#   ['Today is just an anxious day.\r',
#    {'entities': [[17, 28, 'ANXIETY_POSITIVE']]}],
#   ['I’m overwhelmed with anxiety.\r',
#    {'entities': [[4, 28, 'ANXIETY_POSITIVE']]}],
#   ["Absolutely. Once I start worrying, it's hard to stop worrying.\r",
#    {'entities': [[40, 61, 'ANXIETY_POSITIVE']]}],
#   ['My mind keeps racing with negative thoughts.\r',
#    {'entities': [[14, 43, 'ANXIETY_POSITIVE']]}],
#   ["Yes, no matter how much I try, I can't calm my mind or stop worrying about everything.\r",
#    {'entities': [[33, 85, 'ANXIETY_POSITIVE']]}],
#   ["It's like having a runaway train in my head.\r",
#    {'entities': [[19, 43, 'ANXIETY_POSITIVE']]}],
#   ["I can feel a worry starting to creep in, and before I know it, I'm spiraling into catastrophic scenarios.\r",
#    {'entities': [[6, 39, 'ANXIETY_POSITIVE'], [67, 104, 'ANXIETY_POSITIVE']]}],
#   ['I try to distract myself, or reason with myself.\r',
#    {'entities': [[2, 24, 'ANXIETY_POSITIVE'], [29, 47, 'ANXIETY_POSITIVE']]}],
#   ['It’s like fighting a losing battle.\r',
#    {'entities': [[10, 34, 'ANXIETY_POSITIVE']]}],
#   ["Some days, it feels like my mind is racing, and I can’t turn it off, even when I'm exhausted.\r",
#    {'entities': [[25, 42, 'ANXIETY_POSITIVE'], [48, 93, 'ANXIETY_POSITIVE']]}],
#   ["It's incredibly frustrating and exhausting.\r",
#    {'entities': [[5, 27, 'ANXIETY_POSITIVE'], [32, 42, 'ANXIETY_POSITIVE']]}],
#   ["Yeah, it's really hard.\r", {'entities': [[6, 22, 'ANXIETY_POSITIVE']]}],
#   ['It often does.\r', {'entities': [[0, 13, 'ANXIETY_POSITIVE']]}],
#   ["Yes, I often get a racing heart and sometimes I start sweating or my hands tremble when I'm anxious.\r",
#    {'entities': [[19, 31, 'ANXIETY_POSITIVE'],
#      [48, 62, 'ANXIETY_POSITIVE'],
#      [69, 82, 'ANXIETY_POSITIVE'],
#      [88, 99, 'ANXIETY_POSITIVE']]}],
#   ["I get headaches and feel really tense in my muscles when I'm anxious, sometimes to the point where I feel physically sick.\r",
#    {'entities': [[6, 15, 'ANXIETY_POSITIVE'],
#      [20, 37, 'ANXIETY_POSITIVE'],
#      [57, 68, 'ANXIETY_POSITIVE'],
#      [101, 121, 'ANXIETY_POSITIVE']]}],
#   ['Absolutely, it’s like my body goes into overdrive.\r',
#    {'entities': [[25, 49, 'ANXIETY_POSITIVE']]}],
#   ['My heart starts pounding like a drumbeat.\r',
#    {'entities': [[3, 40, 'ANXIETY_POSITIVE']]}],
#   ["I can feel the sweat breaking out, even if it's freezing cold.\r",
#    {'entities': [[15, 61, 'ANXIETY_POSITIVE']]}],
#   ['My hands get shaky / shaky hands\r',
#    {'entities': [[3, 18, 'ANXIETY_POSITIVE'], [21, 26, 'ANXIETY_POSITIVE']]}],
#   ['Sometimes my hands tremble so much I can barely hold something.\r',
#    {'entities': [[13, 26, 'ANXIETY_POSITIVE']]}],
#   ["It's embarrassing and uncomfortable.\r",
#    {'entities': [[5, 17, 'ANXIETY_POSITIVE'], [22, 35, 'ANXIETY_POSITIVE']]}],
#   ['I’ve also noticed that my breathing gets shallow and rapid.\r',
#    {'entities': [[26, 58, 'ANXIETY_POSITIVE']]}],
#   ['I often feel a tightness in my chest.\r',
#    {'entities': [[15, 36, 'ANXIETY_POSITIVE']]}],
#   ["It's like my body is constantly on high alert, even when nothing to be afraid of.\r",
#    {'entities': [[13, 77, 'ANXIETY_POSITIVE']]}],
#   ['It often does.\r', {'entities': [[3, 13, 'ANXIETY_POSITIVE']]}],
#   ["Yes, I tend to avoid social gatherings and sometimes even going out because I'm afraid of feeling anxious.\r",
#    {'entities': [[15, 38, 'ANXIETY_POSITIVE'],
#      [80, 105, 'ANXIETY_POSITIVE']]}],
#   ["I avoid speaking in public and even skip important meetings because I know they'll make me anxious.\r",
#    {'entities': [[2, 26, 'ANXIETY_POSITIVE'], [83, 98, 'ANXIETY_POSITIVE']]}],
#   ["Definitely. It's become a big part of my life.\r",
#    {'entities': [[17, 45, 'ANXIETY_POSITIVE']]}],
#   ["The noise, the people, the feeling of being trapped, it's overwhelming.\r",
#    {'entities': [[27, 51, 'ANXIETY_POSITIVE']]}],
#   ["I find myself avoiding social gatherings, even with close friends, because I'm terrified of having a panic attack.\r",
#    {'entities': [[14, 40, 'ANXIETY_POSITIVE'],
#      [79, 113, 'ANXIETY_POSITIVE']]}],
#   ['Even simple things can be a challenge.\r',
#    {'entities': [[5, 37, 'ANXIETY_POSITIVE']]}],
#   ['I plan my routes carefully to avoid busy times.\r',
#    {'entities': [[30, 46, 'ANXIETY_POSITIVE']]}],
#   ['I often do my shopping online to avoid the stores altogether.\r',
#    {'entities': [[2, 60, 'ANXIETY_POSITIVE']]}],
#   ["It's like my world is shrinking, and it's really frustrating.\r",
#    {'entities': [[22, 31, 'ANXIETY_POSITIVE'], [49, 60, 'ANXIETY_POSITIVE']]}],
#   ["I don't like people and crowded places\r",
#    {'entities': [[2, 19, 'ANXIETY_POSITIVE']]}],
#   ["Definitely. It's hard to focus on work.\r",
#    {'entities': [[17, 38, 'ANXIETY_POSITIVE']]}],
#   ['I feel like my anxiety is straining my relationships with friends and family.\r',
#    {'entities': [[12, 22, 'ANXIETY_POSITIVE'], [26, 35, 'ANXIETY_POSITIVE']]}],
#   ['Yes, my productivity has dropped.\r',
#    {'entities': [[8, 32, 'ANXIETY_POSITIVE']]}],
#   ['I often cancel plans with friends because I feel too anxious to go out.\r',
#    {'entities': [[2, 14, 'ANXIETY_POSITIVE'], [53, 70, 'ANXIETY_POSITIVE']]}],
#   ["It's been a real struggle.\r",
#    {'entities': [[12, 25, 'ANXIETY_POSITIVE']]}],
#   ['My anxiety has completely thrown my life off balance.\r',
#    {'entities': [[26, 52, 'ANXIETY_POSITIVE']]}],
#   ['Simple tasks like getting out of bed or taking a shower can feel like insurmountable challenges.\r',
#    {'entities': [[70, 95, 'ANXIETY_POSITIVE']]}],
#   ['I used to love my job, but now the thought of going in fills me with dread.\r',
#    {'entities': [[55, 74, 'ANXIETY_POSITIVE']]}],
#   ["I've started avoiding social situations.\r",
#    {'entities': [[13, 39, 'ANXIETY_POSITIVE']]}],
#   ["I'm constantly worried about saying or doing the wrong thing.\r",
#    {'entities': [[15, 28, 'ANXIETY_POSITIVE']]}],
#   ['My relationships have suffered too.\r',
#    {'entities': [[17, 30, 'ANXIETY_POSITIVE']]}],
#   ["I've become more withdrawn and irritable.\r",
#    {'entities': [[12, 26, 'ANXIETY_POSITIVE'], [31, 40, 'ANXIETY_POSITIVE']]}],
#   ["It's pushing people away.\r", {'entities': [[5, 24, 'ANXIETY_POSITIVE']]}],
#   ["It's a vicious cycle, and I feel trapped.\r",
#    {'entities': [[28, 40, 'ANXIETY_POSITIVE']]}],
#   ['I have affected by anxiety.\r',
#    {'entities': [[7, 15, 'ANXIETY_POSITIVE']]}],
#   None,
#   ['\r', {'entities': []}],
#   ["Yes, I hear voices talking to me, even when I'm alone. They say things that make me uncomfortable.\r",
#    {'entities': [[0, 54, 'SCHIZOPHRENIA_POSITIVE'],
#      [71, 97, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['I sometimes hear people calling my name or having conversations, but when I look around, no one is there.\r',
#    {'entities': [[2, 16, 'SCHIZOPHRENIA_POSITIVE'],
#      [24, 39, 'SCHIZOPHRENIA_POSITIVE'],
#      [43, 63, 'SCHIZOPHRENIA_POSITIVE'],
#      [89, 104, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Yeah, I hear them all the time.\r',
#    {'entities': [[0, 4, 'SCHIZOPHRENIA_POSITIVE'],
#      [8, 30, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's like there's a whole other world going on inside my head, and sometimes it spills out into the real one.\r",
#    {'entities': [[38, 61, 'SCHIZOPHRENIA_POSITIVE'],
#      [80, 90, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["They can be really loud and clear, like someone's whispering right in my ear, or they can be more distant, like voices in a crowd.\r",
#    {'entities': [[12, 33, 'SCHIZOPHRENIA_POSITIVE'],
#      [40, 60, 'SCHIZOPHRENIA_POSITIVE'],
#      [86, 105, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's hard to explain, but it feels completely real.\r",
#    {'entities': [[29, 50, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Sometimes they're nice, offering advice or encouragement.\r",
#    {'entities': [[24, 56, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Other times, they're mean, saying terrible things about me.\r",
#    {'entities': [[27, 58, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['They can command me to do stuff, or just keep a constant commentary running in the background.\r',
#    {'entities': [[9, 19, 'SCHIZOPHRENIA_POSITIVE'],
#      [57, 93, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's exhausting trying to sort out what's real and what's not.\r",
#    {'entities': [[5, 61, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Most people don't understand, and they think I'm crazy when I try to tell them.\r",
#    {'entities': [[0, 28, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's lonely.\r", {'entities': [[0, 11, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['They are telling me the truth.\r',
#    {'entities': [[9, 19, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['It guides me always.\r',
#    {'entities': [[3, 19, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Yes, I often feel like my neighbors are watching me and reporting my actions to someone.\r',
#    {'entities': [[0, 12, 'SCHIZOPHRENIA_POSITIVE'],
#      [40, 51, 'SCHIZOPHRENIA_POSITIVE'],
#      [56, 76, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Conversations when no one is there.\r',
#    {'entities': [[0, 34, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['I think my coworkers are secretly meeting to discuss how to get me fired.\r',
#    {'entities': [[25, 41, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Yeah, all the time.\r', {'entities': [[0, 18, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I'm being watched,\r", {'entities': [[4, 17, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Every little thing I do, someone's noticing.\r",
#    {'entities': [[25, 43, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Someone looking at me.\r',
#    {'entities': [[0, 21, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I can feel their eyes on me, even when there's no one around.\r",
#    {'entities': [[17, 27, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's creepy.\r", {'entities': [[0, 11, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Sometimes, I think they're planning something, like they're going to hurt me or someone I love.\r",
#    {'entities': [[27, 45, 'SCHIZOPHRENIA_POSITIVE'],
#      [60, 73, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's hard to shake the feeling.\r",
#    {'entities': [[5, 30, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I try to ignore it, but it's always there, lurking in the background.\r",
#    {'entities': [[24, 41, 'SCHIZOPHRENIA_POSITIVE'],
#      [43, 68, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['It makes it tough to trust anyone, even people who care about me.\r',
#    {'entities': [[12, 33, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['All these people are waiting to put me down.\r',
#    {'entities': [[21, 43, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['I can’t go anywhere.\r',
#    {'entities': [[2, 19, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['People are judging my every move.\r',
#    {'entities': [[11, 18, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['There are times when I think people are talking about me, or even plotting against me.\r',
#    {'entities': [[29, 56, 'SCHIZOPHRENIA_POSITIVE'],
#      [66, 85, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['I catch myself looking over my shoulder, wondering if someone is following me. \r',
#    {'entities': [[54, 77, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Yes, sometimes I can't tell if the things I see or hear are real or just in my mind.\r",
#    {'entities': [[0, 14, 'SCHIZOPHRENIA_POSITIVE'],
#      [44, 47, 'SCHIZOPHRENIA_POSITIVE'],
#      [51, 55, 'SCHIZOPHRENIA_POSITIVE'],
#      [60, 83, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["There are moments when I'm not sure if the events happening around me are actually occurring or I'm imagining them.\r",
#    {'entities': [[23, 35, 'SCHIZOPHRENIA_POSITIVE'],
#      [74, 109, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's like living in a fog, you know?\r",
#    {'entities': [[10, 25, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Sometimes it's clear.\r",
#    {'entities': [[0, 20, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["But then there are other times when everything's just...off.\r",
#    {'entities': [[36, 59, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I see things that aren't there, hear voices, and believe things that probably aren't true.\r",
#    {'entities': [[2, 43, 'SCHIZOPHRENIA_POSITIVE'],
#      [49, 89, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's like my brain is playing tricks on me.\r",
#    {'entities': [[22, 42, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's really scary and confusing.\r",
#    {'entities': [[22, 31, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I never know when it's going to happen, and it makes it hard to trust myself or anyone else.\r",
#    {'entities': [[0, 38, 'SCHIZOPHRENIA_POSITIVE'],
#      [56, 69, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['I have to check the things again after I done it.\r',
#    {'entities': [[10, 32, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['It feels like two worlds.\r',
#    {'entities': [[3, 24, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Someone is watching me or controlling my thoughts.\r',
#    {'entities': [[0, 22, 'SCHIZOPHRENIA_POSITIVE'],
#      [26, 49, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['My mind is racing ahead, jumping to conclusions.\r',
#    {'entities': [[25, 47, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['It’s hard to ignore them.\r',
#    {'entities': [[5, 24, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['I see things others can’t or hear voices that no one else can hear.\r',
#    {'entities': [[2, 25, 'SCHIZOPHRENIA_POSITIVE'],
#      [29, 66, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Yes, my thoughts often feel jumbled.\r',
#    {'entities': [[0, 35, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I can't focus on tasks like I used to.\r",
#    {'entities': [[2, 22, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's really hard for me to concentrate on reading or watching TV because my mind keeps wandering.\r",
#    {'entities': [[12, 41, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Yeah, it's like my brain is in overdrive.\r",
#    {'entities': [[19, 40, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["One minute I'm thinking about a million things at once, and the next, I can't focus on anything.\r",
#    {'entities': [[24, 54, 'SCHIZOPHRENIA_POSITIVE'],
#      [72, 95, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["There's too much noise in my head.\r",
#    {'entities': [[8, 33, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Sometimes, I get lost in my thoughts and lose track of what I'm doing.\r",
#    {'entities': [[13, 36, 'SCHIZOPHRENIA_POSITIVE'],
#      [41, 69, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's hard to keep up with conversations or remember simple things.\r",
#    {'entities': [[5, 65, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['It feels like my mind is playing tricks on me.\r',
#    {'entities': [[17, 45, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's exhausting trying to stay focused.\r",
#    {'entities': [[5, 38, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['I find myself getting lost or missing important parts.\r',
#    {'entities': [[14, 53, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's frustrating.\r", {'entities': [[5, 16, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I know I'm capable of more, but it feels like my brain is working against me.\r",
#    {'entities': [[49, 76, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["There's a constant noise in my mind, making it difficult to focus.\r",
#    {'entities': [[19, 35, 'SCHIZOPHRENIA_POSITIVE'],
#      [37, 65, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Sometimes, words get mixed up in my head, and it takes extra effort to find the right ones.\r',
#    {'entities': [[11, 29, 'SCHIZOPHRENIA_POSITIVE'],
#      [46, 90, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Thoughts that used to be clear and easy to follow now feel scattered and distant.\r',
#    {'entities': [[54, 80, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's hard to concentrate on one thing for very long.\r",
#    {'entities': [[5, 51, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's like my mind has become a fog.\r",
#    {'entities': [[13, 34, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Yes, I've been having trouble keeping up with my job.\r",
#    {'entities': [[0, 52, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['My relationships are suffering because of my strange thoughts.\r',
#    {'entities': [[17, 30, 'SCHIZOPHRENIA_POSITIVE'],
#      [42, 61, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I can't maintain a routine or keep in touch with friends because I feel so disconnected and my behaviors seem odd to others.\r",
#    {'entities': [[2, 26, 'SCHIZOPHRENIA_POSITIVE'],
#      [67, 87, 'SCHIZOPHRENIA_POSITIVE'],
#      [92, 123, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["Definitely. It's a constant struggle.\r",
#    {'entities': [[0, 36, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['The voices and strange thoughts can really throw me off track.\r',
#    {'entities': [[4, 61, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I used to be able to hold down a job and have friends, but now it's hard to even get out of bed some days.\r",
#    {'entities': [[68, 88, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I find myself isolating because I'm afraid of what people might think of me or how I might act.\r",
#    {'entities': [[2, 23, 'SCHIZOPHRENIA_POSITIVE'],
#      [36, 75, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Even simple tasks can be overwhelming like taking a shower or cooking a meal because of the voices or strange ideas in my head.\r',
#    {'entities': [[18, 37, 'SCHIZOPHRENIA_POSITIVE'],
#      [88, 126, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's like there's a battle going on inside me, and I'm losing.\r",
#    {'entities': [[20, 45, 'SCHIZOPHRENIA_POSITIVE'],
#      [51, 61, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['Simple things can feel like impossible tasks like getting dressed or making breakfast.\r',
#    {'entities': [[0, 44, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["It's hard to focus on what needs to be done when my mind is racing in a different direction.\r",
#    {'entities': [[52, 91, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['It’s a struggle.\r', {'entities': [[0, 15, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I want to connect with people, but it’s difficult to maintain conversations when I'm preoccupied with unusual ideas.\r",
#    {'entities': [[40, 75, 'SCHIZOPHRENIA_POSITIVE'],
#      [85, 115, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["People often misunderstand me and it feels like I'm pushing them away\r",
#    {'entities': [[0, 29, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ["I've lost friends because of it. It's a lonely feeling.\r",
#    {'entities': [[33, 54, 'SCHIZOPHRENIA_POSITIVE']]}],
#   ['The voices or strange thoughts take over, and I lose track of time.\r',
#    {'entities': [[4, 30, 'SCHIZOPHRENIA_POSITIVE'],
#      [48, 66, 'SCHIZOPHRENIA_POSITIVE']]}],
#   None,
#   ['\r', {'entities': []}],
#   ["Yes, I feel sad and down almost every day, even when there's no specific reason.\r",
#    {'entities': [[0, 3, 'DEPRESSION_POSITIVE'],
#      [12, 41, 'DEPRESSION_POSITIVE'],
#      [48, 79, 'DEPRESSION_POSITIVE']]}],
#   ["I can't shake off this feeling of sadness.\r",
#    {'entities': [[2, 41, 'DEPRESSION_POSITIVE']]}],
#   ["It's like a weight on me.\r",
#    {'entities': [[12, 24, 'DEPRESSION_POSITIVE']]}],
#   ["It's hard to put into words, but yeah, I guess you could say that.\r",
#    {'entities': [[5, 27, 'DEPRESSION_POSITIVE']]}],
#   ["It's been like this for what feels like forever.\r",
#    {'entities': [[29, 47, 'DEPRESSION_POSITIVE']]}],
#   ["I wake up feeling heavy, like there's a dark cloud hanging over me all day.\r",
#    {'entities': [[2, 23, 'DEPRESSION_POSITIVE']]}],
#   ["Even things I used to enjoy, like hanging out with friends or doing hobbies, just don't feel the same anymore.\r",
#    {'entities': [[77, 109, 'DEPRESSION_POSITIVE']]}],
#   ["It's like color has drained from my world.\r",
#    {'entities': [[10, 27, 'DEPRESSION_POSITIVE']]}],
#   ["I find myself tired, even when I've slept enough.\r",
#    {'entities': [[14, 48, 'DEPRESSION_POSITIVE']]}],
#   ["My mind races with negative thoughts, and it's hard to concentrate on anything.\r",
#    {'entities': [[3, 36, 'DEPRESSION_POSITIVE'],
#      [47, 78, 'DEPRESSION_POSITIVE']]}],
#   ['There are days when getting out of bed feels like climbing a mountain.\r',
#    {'entities': [[15, 69, 'DEPRESSION_POSITIVE']]}],
#   ["I feel so isolated and alone, even when I'm surrounded by people.\r",
#    {'entities': [[2, 28, 'DEPRESSION_POSITIVE']]}],
#   ["It's a struggle to get through the day.\r",
#    {'entities': [[7, 38, 'DEPRESSION_POSITIVE']]}],
#   ['It feels like a heavy weight is pressing down on me.\r',
#    {'entities': [[3, 28, 'DEPRESSION_POSITIVE']]}],
#   ["I can't shake this overwhelming sadness, no matter what I do.\r",
#    {'entities': [[19, 39, 'DEPRESSION_POSITIVE'],
#      [41, 60, 'DEPRESSION_POSITIVE']]}],
#   ['Nothing interests me anymore.\r',
#    {'entities': [[0, 28, 'DEPRESSION_POSITIVE']]}],
#   ["It's an emptiness.\r", {'entities': [[0, 17, 'DEPRESSION_POSITIVE']]}],
#   ['I feel numb and disconnected from everything.\r',
#    {'entities': [[2, 11, 'DEPRESSION_POSITIVE'],
#      [16, 44, 'DEPRESSION_POSITIVE']]}],
#   ["I don't know, maybe a little.\r",
#    {'entities': [[14, 28, 'DEPRESSION_POSITIVE']]}],
#   ["I can't imagine feeling happy.\r",
#    {'entities': [[2, 29, 'DEPRESSION_POSITIVE']]}],
#   ["Yes, things I used to enjoy just don't interest me anymore.\r",
#    {'entities': [[33, 58, 'DEPRESSION_POSITIVE']]}],
#   ["I don't feel motivated to do anything.\r",
#    {'entities': [[2, 37, 'DEPRESSION_POSITIVE']]}],
#   ["I don't find pleasure in my hobbies or socializing with friends like I used to.\r",
#    {'entities': [[2, 21, 'DEPRESSION_POSITIVE']]}],
#   ['Used to be, I could lose myself in.\r',
#    {'entities': [[14, 34, 'DEPRESSION_POSITIVE']]}],
#   ['It was like a whole different world.\r',
#    {'entities': [[7, 35, 'DEPRESSION_POSITIVE']]}],
#   ['Now, it’s just...empty.\r',
#    {'entities': [[10, 22, 'DEPRESSION_POSITIVE']]}],
#   ['There’s no excitement, no joy.\r',
#    {'entities': [[8, 21, 'DEPRESSION_POSITIVE'],
#      [23, 29, 'DEPRESSION_POSITIVE']]}],
#   ['It feels like I’m going through the motions, but nothing really sticks.\r',
#    {'entities': [[49, 70, 'DEPRESSION_POSITIVE']]}],
#   ['It’s just another day.\r', {'entities': [[5, 21, 'DEPRESSION_POSITIVE']]}],
#   ['It’s like the fun has been sucked out of everything.\r',
#    {'entities': [[14, 51, 'DEPRESSION_POSITIVE']]}],
#   ['Things I used to love now feel completely pointless.\r',
#    {'entities': [[26, 51, 'DEPRESSION_POSITIVE']]}],
#   ["There's no joy or excitement in it anymore.\r",
#    {'entities': [[8, 28, 'DEPRESSION_POSITIVE']]}],
#   ["I just don't get the same satisfaction from things I used to enjoy.\r",
#    {'entities': [[7, 38, 'DEPRESSION_POSITIVE']]}],
#   ["I've lost interest in almost everything.\r",
#    {'entities': [[5, 18, 'DEPRESSION_POSITIVE']]}],
#   ['Nothing seems worth doing.\r',
#    {'entities': [[0, 25, 'DEPRESSION_POSITIVE']]}],
#   ['Thought of doing it fills me with dread.\r',
#    {'entities': [[20, 39, 'DEPRESSION_POSITIVE']]}],
#   ["I can't focus or find any pleasure.\r",
#    {'entities': [[2, 34, 'DEPRESSION_POSITIVE']]}],
#   ['Social interactions feel exhausting and unrewarding.\r',
#    {'entities': [[20, 51, 'DEPRESSION_POSITIVE']]}],
#   ["It's hard to explain to anyone.\r",
#    {'entities': [[5, 30, 'DEPRESSION_POSITIVE']]}],
#   ["Not really, but it's not as fun as it used to be.\r",
#    {'entities': [[21, 48, 'DEPRESSION_POSITIVE']]}],
#   ['I have a lot of trouble falling asleep and often wake up in the middle of the night.\r',
#    {'entities': [[9, 38, 'DEPRESSION_POSITIVE'],
#      [49, 83, 'DEPRESSION_POSITIVE']]}],
#   ["I sleep a lot more than usual, sometimes staying in bed all day because I just don't have the energy to get up.\r",
#    {'entities': [[2, 29, 'DEPRESSION_POSITIVE'],
#      [79, 110, 'DEPRESSION_POSITIVE']]}],
#   ["It's a nightmare, really.\r",
#    {'entities': [[7, 16, 'DEPRESSION_POSITIVE']]}],
#   ["I either can't sleep at all or I'm drowning in sleep.\r",
#    {'entities': [[9, 27, 'DEPRESSION_POSITIVE'],
#      [31, 52, 'DEPRESSION_POSITIVE']]}],
#   ["When I do manage to fall asleep, it's restless and I wake up feeling more exhausted than before.\r",
#    {'entities': [[61, 83, 'DEPRESSION_POSITIVE']]}],
#   ["My mind won't shut off, racing with thoughts.\r",
#    {'entities': [[3, 22, 'DEPRESSION_POSITIVE'],
#      [24, 44, 'DEPRESSION_POSITIVE']]}],
#   ['There are days when I could sleep for a week.\r',
#    {'entities': [[20, 44, 'DEPRESSION_POSITIVE']]}],
#   ['I feel like a zombie, dragging myself through the day,\r',
#    {'entities': [[2, 20, 'DEPRESSION_POSITIVE'],
#      [22, 53, 'DEPRESSION_POSITIVE']]}],
#   ["Nothing wakes me up, and I'm tired, no matter how much I sleep.\r",
#    {'entities': [[25, 62, 'DEPRESSION_POSITIVE']]}],
#   ["I can't turn my brain off at night.\r",
#    {'entities': [[2, 34, 'DEPRESSION_POSITIVE']]}],
#   ['My mind races with worries and problems, making it impossible to fall asleep.\r',
#    {'entities': [[3, 39, 'DEPRESSION_POSITIVE']]}],
#   ["I'm tired. No matter how much sleep I get.\r",
#    {'entities': [[4, 10, 'DEPRESSION_POSITIVE'],
#      [11, 42, 'DEPRESSION_POSITIVE']]}],
#   ['I have no energy during the day.\r',
#    {'entities': [[2, 16, 'DEPRESSION_POSITIVE']]}],
#   ['I spend most of time sleeping to escape how I feel.\r',
#    {'entities': [[2, 29, 'DEPRESSION_POSITIVE']]}],
#   ["It's a vicious cycle.\r", {'entities': [[7, 20, 'DEPRESSION_POSITIVE']]}],
#   ['Wake me up in a panic.\r', {'entities': [[0, 21, 'DEPRESSION_POSITIVE']]}],
#   ['Sleeping is the only time I feel somewhat at peace.\r',
#    {'entities': [[16, 50, 'DEPRESSION_POSITIVE']]}],
#   ['Way to avoid dealing with everything else.\r',
#    {'entities': [[0, 41, 'DEPRESSION_POSITIVE']]}],
#   ["Yes, I feel exhausted all the time, even when I haven't done much.\r",
#    {'entities': [[12, 34, 'DEPRESSION_POSITIVE']]}],
#   ['I have very little energy and feel tired almost every day, no matter how much I rest.\r',
#    {'entities': [[7, 25, 'DEPRESSION_POSITIVE'],
#      [30, 40, 'DEPRESSION_POSITIVE']]}],
#   ["It's like I'm carrying a lead weight around all the time.\r",
#    {'entities': [[10, 56, 'DEPRESSION_POSITIVE']]}],
#   ["I'm exhausted even after sleeping what feels like forever.\r",
#    {'entities': [[4, 33, 'DEPRESSION_POSITIVE']]}],
#   ['Getting out of bed in the morning is a battle, and just getting through the day is a huge effort.\r',
#    {'entities': [[0, 45, 'DEPRESSION_POSITIVE'],
#      [51, 96, 'DEPRESSION_POSITIVE']]}],
#   ['I used to have so much energy, but now, even simple tasks like taking a shower or making dinner feel overwhelming.\r',
#    {'entities': [[96, 113, 'DEPRESSION_POSITIVE']]}],
#   ["It's like my body is running on empty, and no matter how much rest I get, I can't recharge.\r",
#    {'entities': [[21, 37, 'DEPRESSION_POSITIVE'],
#      [76, 90, 'DEPRESSION_POSITIVE']]}],
#   ["It's like I'm carrying a heavy weight around.\r",
#    {'entities': [[14, 44, 'DEPRESSION_POSITIVE']]}],
#   ['I have no energy to do anything.\r',
#    {'entities': [[2, 16, 'DEPRESSION_POSITIVE']]}],
#   ['My body feels like lead, and my mind is foggy.\r',
#    {'entities': [[32, 45, 'DEPRESSION_POSITIVE']]}],
#   ["It's hard to concentrate or focus on anything.\r",
#    {'entities': [[5, 45, 'DEPRESSION_POSITIVE']]}],
#   ['I have no interest in doing anything.\r',
#    {'entities': [[2, 18, 'DEPRESSION_POSITIVE']]}],
#   ['Fatigue has taken over my life.\r',
#    {'entities': [[0, 30, 'DEPRESSION_POSITIVE']]}],
#   ['I feel weak and achy all the time.\r',
#    {'entities': [[2, 20, 'DEPRESSION_POSITIVE']]}],
#   ["I can't think clearly.\r", {'entities': [[2, 21, 'DEPRESSION_POSITIVE']]}],
#   ["It's like my brain is moving in slow motion.\r",
#    {'entities': [[13, 43, 'DEPRESSION_POSITIVE']]}],
#   ["I don't know how to describe it.\r",
#    {'entities': [[4, 31, 'DEPRESSION_POSITIVE']]}],
#   ['I just feel drained.\r', {'entities': [[12, 19, 'DEPRESSION_POSITIVE']]}],
#   ["Yes, I often feel worthless and think that I'm a burden to others.\r",
#    {'entities': [[13, 27, 'DEPRESSION_POSITIVE'],
#      [49, 65, 'DEPRESSION_POSITIVE']]}],
#   ["I feel guilty about things that aren't really my fault, and I can't stop blaming myself.\r",
#    {'entities': [[2, 26, 'DEPRESSION_POSITIVE'],
#      [62, 87, 'DEPRESSION_POSITIVE']]}],
#   ["It's like I'm a total failure.\r",
#    {'entities': [[10, 29, 'DEPRESSION_POSITIVE']]}],
#   ['I blame myself for everything that goes wrong, no matter how small.\r',
#    {'entities': [[2, 29, 'DEPRESSION_POSITIVE']]}],
#   ['I feel so worthless, like a burden to everyone.\r',
#    {'entities': [[2, 19, 'DEPRESSION_POSITIVE'],
#      [28, 46, 'DEPRESSION_POSITIVE']]}],
#   ['I keep replaying past mistakes, and the guilt is overwhelming.\r',
#    {'entities': [[40, 61, 'DEPRESSION_POSITIVE']]}],
#   ["I don't deserve to be happy or successful.\r",
#    {'entities': [[2, 41, 'DEPRESSION_POSITIVE']]}],
#   ["I'm convinced that everyone would be better off without me.\r",
#    {'entities': [[19, 58, 'DEPRESSION_POSITIVE']]}],
#   ['I feel completely worthless.\r',
#    {'entities': [[2, 27, 'DEPRESSION_POSITIVE']]}],
#   ["I'm a burden to everyone and don't deserve to be here.\r",
#    {'entities': [[29, 53, 'DEPRESSION_POSITIVE']]}],
#   ["I'm blaming myself for everything that goes wrong.\r",
#    {'entities': [[4, 33, 'DEPRESSION_POSITIVE']]}],
#   ['I hate myself.\r', {'entities': [[2, 13, 'DEPRESSION_POSITIVE']]}],
#   ['I feel so disgusted with who I am.\r',
#    {'entities': [[2, 19, 'DEPRESSION_POSITIVE']]}],
#   ["I can't shake the feeling that I've ruined everyone's life.\r",
#    {'entities': [[36, 58, 'DEPRESSION_POSITIVE']]}],
#   ['I push people away.\r', {'entities': [[2, 18, 'DEPRESSION_POSITIVE']]}],
#   ["I don't deserve love or friendship of others.\r",
#    {'entities': [[2, 34, 'DEPRESSION_POSITIVE']]}],
#   ["I believe I'm a failure and a disappointment.\r",
#    {'entities': [[10, 44, 'DEPRESSION_POSITIVE']]}],
#   ["It's hard to talk about.\r",
#    {'entities': [[5, 23, 'DEPRESSION_POSITIVE']]}],
#   ['I just feel like a bad person.\r',
#    {'entities': [[7, 29, 'DEPRESSION_POSITIVE']]}],
#   None,
#   ['\r', {'entities': []}],
#   ["Yes, I've been feeling incredibly happy and on top of the world for days now. It's like nothing can bring me down.\r",
#    {'entities': [[23, 63, 'MANIA_POSITIVE'], [88, 113, 'MANIA_POSITIVE']]}],
#   ["I feel an intense joy and excitement all the time, much more than usual. It's almost liked a constant high.\r",
#    {'entities': [[7, 36, 'MANIA_POSITIVE']]}],
#   ["Unusually happy. Euphoria. Elevated mood. I'm on top of the world right now.\r",
#    {'entities': [[0, 16, 'MANIA_POSITIVE'],
#      [27, 41, 'MANIA_POSITIVE'],
#      [46, 65, 'MANIA_POSITIVE']]}],
#   ["It's like this incredible energy is coursing through me, and every idea is a million-dollar concept.\r",
#    {'entities': [[15, 32, 'MANIA_POSITIVE'], [61, 99, 'MANIA_POSITIVE']]}],
#   ["I can't stop thinking, and everything exciting and full of possibilities.\r",
#    {'entities': [[2, 21, 'MANIA_POSITIVE'],
#      [27, 46, 'MANIA_POSITIVE'],
#      [51, 72, 'MANIA_POSITIVE']]}],
#   ["It's been going on for what feels like forever days, weeks, I'm unstoppable. I've got plans to change the world.\r",
#    {'entities': [[60, 76, 'MANIA_POSITIVE']]}],
#   ["This is the best I've ever felt. Why wouldn't I be happy?\r",
#    {'entities': [[33, 56, 'MANIA_POSITIVE']]}],
#   ["I've been on top of the world.\r",
#    {'entities': [[13, 30, 'MANIA_POSITIVE']]}],
#   ['I can conquer the world.\r', {'entities': [[6, 23, 'MANIA_POSITIVE']]}],
#   ['I have endless energy.\r', {'entities': [[2, 21, 'MANIA_POSITIVE']]}],
#   ['I can go days without sleep and still feel hyperactive and focused.\r',
#    {'entities': [[38, 66, 'MANIA_POSITIVE']]}],
#   ["I've been making impulsive decisions.\r",
#    {'entities': [[17, 36, 'MANIA_POSITIVE']]}],
#   ['I feel energized and ready to go all the time.\r',
#    {'entities': [[2, 16, 'MANIA_POSITIVE']]}],
#   ['I have high sex drive.\r', {'entities': [[7, 21, 'MANIA_POSITIVE']]}],
#   ['I feel incredibly attractive and desirable.\r',
#    {'entities': [[2, 42, 'MANIA_POSITIVE']]}],
#   ['Everyone has their ups and downs.\r',
#    {'entities': [[19, 22, 'MANIA_POSITIVE'], [27, 33, 'MANIA_POSITIVE']]}],
#   ["It's hard to explain.\r", {'entities': [[5, 20, 'MANIA_POSITIVE']]}],
#   ["Yes, I have so much energy that I don't need to sleep more than a few hours. I just can't sit still.\r",
#    {'entities': [[12, 26, 'MANIA_POSITIVE'], [84, 99, 'MANIA_POSITIVE']]}],
#   ['I feel like I can keep going without getting tired, even if I only sleep a couple of hours a night.\r',
#    {'entities': [[18, 50, 'MANIA_POSITIVE']]}],
#   ["I'm like a human battery in overdrive. I could conquer the world right now.\r",
#    {'entities': [[11, 38, 'MANIA_POSITIVE'], [47, 64, 'MANIA_POSITIVE']]}],
#   ["I've been running on pure adrenaline for days.\r",
#    {'entities': [[10, 36, 'MANIA_POSITIVE']]}],
#   ["I've got so much to do, so many ideas, I can't even sit still.\r",
#    {'entities': [[12, 22, 'MANIA_POSITIVE'],
#      [27, 37, 'MANIA_POSITIVE'],
#      [41, 61, 'MANIA_POSITIVE']]}],
#   ["It's like my brain is on fire, and my body just can't keep up.\r",
#    {'entities': [[13, 29, 'MANIA_POSITIVE']]}],
#   ["I've been going nonstop, and I'm loving every minute of it. I feel invincible.\r",
#    {'entities': [[10, 23, 'MANIA_POSITIVE'], [62, 77, 'MANIA_POSITIVE']]}],
#   ["I can't stop moving.\r", {'entities': [[2, 19, 'MANIA_POSITIVE']]}],
#   ["I've been up for days and I'm still going strong.\r",
#    {'entities': [[5, 21, 'MANIA_POSITIVE'], [30, 48, 'MANIA_POSITIVE']]}],
#   ["I don't know what to do with myself.\r",
#    {'entities': [[2, 35, 'MANIA_POSITIVE']]}],
#   ["My mind is racing, and I can't control my impulses.\r",
#    {'entities': [[25, 50, 'MANIA_POSITIVE']]}],
#   ["I've been spending money like crazy.\r",
#    {'entities': [[10, 35, 'MANIA_POSITIVE']]}],
#   ['Making rash decisions.\r', {'entities': [[0, 21, 'MANIA_POSITIVE']]}],
#   ["It's hard to focus on anything.\r",
#    {'entities': [[5, 18, 'MANIA_POSITIVE']]}],
#   ["I've been busy.\r", {'entities': [[1, 14, 'MANIA_POSITIVE']]}],
#   ["I'm just feeling really good and motivated.\r",
#    {'entities': [[9, 28, 'MANIA_POSITIVE'], [33, 42, 'MANIA_POSITIVE']]}],
#   ['My mind is jumping from one thing to the next.\r',
#    {'entities': [[3, 18, 'MANIA_POSITIVE']]}],
#   ["Yes, I've started multiple new projects and activities. I feel like I can do everything at once.\r",
#    {'entities': [[10, 55, 'MANIA_POSITIVE'], [70, 95, 'MANIA_POSITIVE']]}],
#   ["I've been so productive and busy. I can't stop myself from jumping into new ventures.\r",
#    {'entities': [[13, 33, 'MANIA_POSITIVE']]}],
#   ["I'm like a tornado. I've got so much energy.\r",
#    {'entities': [[29, 43, 'MANIA_POSITIVE']]}],
#   ["I don't know what to do with myself.\r",
#    {'entities': [[2, 35, 'MANIA_POSITIVE']]}],
#   ["I'm starting new businesses, writing books, learning new languages, more works, all at the same time.\r",
#    {'entities': [[68, 78, 'MANIA_POSITIVE'], [80, 100, 'MANIA_POSITIVE']]}],
#   ["I can't stop, won't stop. I'm on a mission to change the world, and I'm the only one who can do it.\r",
#    {'entities': [[35, 62, 'MANIA_POSITIVE']]}],
#   ["I've got a million ideas, and I'm going to make them all happen. I'm unstoppable.\r",
#    {'entities': [[11, 24, 'MANIA_POSITIVE'], [43, 64, 'MANIA_POSITIVE']]}],
#   ['I need to be doing something all the time.\r',
#    {'entities': [[2, 41, 'MANIA_POSITIVE']]}],
#   ["I've started so many new projects.\r",
#    {'entities': [[5, 33, 'MANIA_POSITIVE']]}],
#   ['I have all these brilliant ideas.\r',
#    {'entities': [[7, 32, 'MANIA_POSITIVE']]}],
#   ['I need to do all at once.\r', {'entities': [[10, 24, 'MANIA_POSITIVE']]}],
#   ["I can't slow down.\r", {'entities': [[2, 18, 'MANIA_POSITIVE']]}],
#   ["I can't focus on one thing at a time.\r",
#    {'entities': [[2, 36, 'MANIA_POSITIVE']]}],
#   ['I get bored easily and jump from one thing to the next.\r',
#    {'entities': [[6, 18, 'MANIA_POSITIVE'], [23, 54, 'MANIA_POSITIVE']]}],
#   ["I'm not thinking about the consequences of my actions.\r",
#    {'entities': [[4, 39, 'MANIA_POSITIVE']]}],
#   ['I just want to do everything and anything.\r',
#    {'entities': [[7, 28, 'MANIA_POSITIVE']]}],
#   ["It's not unusual for me.\r", {'entities': [[5, 23, 'MANIA_POSITIVE']]}],
#   ['Yes, my thoughts are racing, and I talk so fast that people have a hard time keeping up with me.\r',
#    {'entities': [[0, 27, 'MANIA_POSITIVE']]}],
#   ["I can't slow down my speech, and my mind feels like it's going a mile a minute with so many ideas.\r",
#    {'entities': [[2, 27, 'MANIA_POSITIVE'], [41, 78, 'MANIA_POSITIVE']]}],
#   ['You have no idea. My brain is a non-stop rollercoaster.\r',
#    {'entities': [[32, 54, 'MANIA_POSITIVE']]}],
#   ['Words pouring out faster than I can think.\r',
#    {'entities': [[0, 41, 'MANIA_POSITIVE']]}],
#   ["It's like there's a million ideas exploding in my head all at once.\r",
#    {'entities': [[20, 54, 'MANIA_POSITIVE']]}],
#   ["I can't shut off. I've got to get it all out.\r",
#    {'entities': [[2, 17, 'MANIA_POSITIVE']]}],
#   ["It's overwhelming, but it's also exhilarating.\r",
#    {'entities': [[5, 17, 'MANIA_POSITIVE'], [33, 45, 'MANIA_POSITIVE']]}],
#   ["It's like I'm on fire with creativity.\r",
#    {'entities': [[10, 21, 'MANIA_POSITIVE']]}],
#   ['My thoughts are coming out faster than I can say them.\r',
#    {'entities': [[3, 33, 'MANIA_POSITIVE']]}],
#   ["I can't focus on one thing.\r", {'entities': [[2, 26, 'MANIA_POSITIVE']]}],
#   ["It's overwhelming.\r", {'entities': [[5, 17, 'MANIA_POSITIVE']]}],
#   ["I can't concentrate on anything.\r",
#    {'entities': [[2, 31, 'MANIA_POSITIVE']]}],
#   ["I feel like I'm talking really fast.\r",
#    {'entities': [[12, 35, 'MANIA_POSITIVE']]}],
#   ["I'm talking without thinking.\r",
#    {'entities': [[4, 28, 'MANIA_POSITIVE']]}],
#   ["I can't slow down, even if I try.\r",
#    {'entities': [[2, 17, 'MANIA_POSITIVE']]}],
#   ['I say whatever comes to mind.\r',
#    {'entities': [[6, 28, 'MANIA_POSITIVE']]}],
#   ['I just feel excited.\r', {'entities': [[7, 19, 'MANIA_POSITIVE']]}],
#   ["Yes, I've been spending a lot of money on unnecessary things and making impulsive decisions.\r",
#    {'entities': [[15, 60, 'MANIA_POSITIVE'], [65, 91, 'MANIA_POSITIVE']]}],
#   ["I've been taking more risks lately, like driving fast and making spur-of-the-moment choices without thinking them through.\r",
#    {'entities': [[10, 27, 'MANIA_POSITIVE'], [41, 53, 'MANIA_POSITIVE']]}],
#   ["I'm living life to the fullest. I've been on the wildest spending spree ever.\r",
#    {'entities': [[4, 31, 'MANIA_POSITIVE'], [49, 71, 'MANIA_POSITIVE']]}],
#   ["Who needs a budget when you're destined for greatness.\r",
#    {'entities': [[31, 53, 'MANIA_POSITIVE']]}],
#   ['I bought a new car, a motorcycle, and a plane ticket to Bali.\r',
#    {'entities': [[2, 60, 'MANIA_POSITIVE']]}],
#   ["I'm a speed demon.\r", {'entities': [[0, 17, 'MANIA_POSITIVE']]}],
#   ['I feel invincible behind the wheel.\r',
#    {'entities': [[2, 34, 'MANIA_POSITIVE']]}],
#   ["Sure, I've made some impulsive decisions, but hey, that's what life about. Taking chances and going for it.\r",
#    {'entities': [[16, 40, 'MANIA_POSITIVE']]}],
#   ["I've been on a shopping spree.\r",
#    {'entities': [[15, 29, 'MANIA_POSITIVE']]}],
#   ['I bought everything I saw, without even thinking about the cost.\r',
#    {'entities': [[2, 25, 'MANIA_POSITIVE'], [27, 63, 'MANIA_POSITIVE']]}],
#   ["I've made some really stupid decisions lately.\r",
#    {'entities': [[5, 38, 'MANIA_POSITIVE']]}],
#   ["I can't stop spending money.\r",
#    {'entities': [[2, 27, 'MANIA_POSITIVE']]}],
#   ["I've gotten involved in a really intense relationship.\r",
#    {'entities': [[33, 53, 'MANIA_POSITIVE']]}],
#   ["I've been using drugs and alcohol more than usual.\r",
#    {'entities': [[34, 49, 'MANIA_POSITIVE']]}],
#   ["I've been making some changes in my life.\r",
#    {'entities': [[10, 40, 'MANIA_POSITIVE']]}],
#   None,
#   ['\r', {'entities': []}],
#   ["Yes, I have times when I feel on top of the world, but then I'll crash and feel deeply depressed.\r",
#    {'entities': [[30, 49, 'BIPOLARDISORDER_POSITIVE'],
#      [80, 96, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I go through phases where I'm extremely happy and energetic, but then I'll hit a low point where I feel very sad and hopeless.(Extremely happiness, deep sadness)\r",
#    {'entities': [[30, 59, 'BIPOLARDISORDER_POSITIVE'],
#      [104, 126, 'BIPOLARDISORDER_POSITIVE'],
#      [127, 160, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["It's like a rollercoaster.\r",
#    {'entities': [[0, 26, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["One minute I'm on top of the world, invincible, and full of energy.\r",
#    {'entities': [[15, 34, 'BIPOLARDISORDER_POSITIVE'],
#      [36, 46, 'BIPOLARDISORDER_POSITIVE'],
#      [52, 66, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['I can conquer anything.\r',
#    {'entities': [[0, 22, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I'm laughing, talking a mile a minute, and have plans to change the world.\r",
#    {'entities': [[4, 12, 'BIPOLARDISORDER_POSITIVE'],
#      [14, 37, 'BIPOLARDISORDER_POSITIVE'],
#      [43, 73, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['But then, like a switch, it flips.\r',
#    {'entities': [[10, 23, 'BIPOLARDISORDER_POSITIVE'],
#      [25, 33, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['The world turns gray, and everything feels heavy.\r',
#    {'entities': [[10, 20, 'BIPOLARDISORDER_POSITIVE'],
#      [26, 48, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I can't get out of bed, I don't want to eat, and the simplest tasks feel impossible.\r",
#    {'entities': [[26, 43, 'BIPOLARDISORDER_POSITIVE'],
#      [53, 83, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["It's like I'm drowning in a sea of hopelessness.\r",
#    {'entities': [[14, 47, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["These swings happen over and over, and it's exhausting.\r",
#    {'entities': [[6, 33, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['I never know what to expect next.\r',
#    {'entities': [[2, 32, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['Up and down.\r', {'entities': [[0, 11, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I go through these cycles where I'm incredibly happy and confident.\r",
#    {'entities': [[36, 66, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['I crash and burn.\r', {'entities': [[2, 16, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['I have no control over my emotions.\r',
#    {'entities': [[2, 34, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['I feel like out of control.\r',
#    {'entities': [[2, 26, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["Once I'm euphoric and the next/suddenly I'm crying uncontrollably.\r",
#    {'entities': [[5, 17, 'BIPOLARDISORDER_POSITIVE'],
#      [44, 65, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['I crash into a deep depression.\r',
#    {'entities': [[2, 30, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['These mood swings disrupt my life. \r',
#    {'entities': [[6, 33, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["Yes, there are days when I can't stop moving and feel like I can do anything, but then there are days when I can't get out of bed.\r",
#    {'entities': [[27, 44, 'BIPOLARDISORDER_POSITIVE'],
#      [61, 76, 'BIPOLARDISORDER_POSITIVE'],
#      [109, 129, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I sometimes feel supercharged and take on a lot, but other times I feel completely drained and can't do much of anything.\r",
#    {'entities': [[17, 29, 'BIPOLARDISORDER_POSITIVE'],
#      [72, 90, 'BIPOLARDISORDER_POSITIVE'],
#      [95, 120, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["It's like living two different lives.\r",
#    {'entities': [[10, 36, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I'm bouncing off the walls.\r",
#    {'entities': [[4, 26, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I have endless energy, and I can't stop moving.\r",
#    {'entities': [[7, 21, 'BIPOLARDISORDER_POSITIVE'],
#      [29, 46, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I'm tackling a million projects at once, and I feel invincible.\r",
#    {'entities': [[47, 62, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["It's like a switch flips.\r",
#    {'entities': [[12, 24, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['The energy drains out of me.\r',
#    {'entities': [[4, 27, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['I can barely get out of bed, and even the simplest tasks feel overwhelming.\r',
#    {'entities': [[6, 27, 'BIPOLARDISORDER_POSITIVE'],
#      [42, 74, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I'm constantly tired, and nothing interests me.\r",
#    {'entities': [[4, 20, 'BIPOLARDISORDER_POSITIVE'],
#      [26, 46, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["It's like being on a rollercoaster, with no control over where I'm going next.\r",
#    {'entities': [[10, 34, 'BIPOLARDISORDER_POSITIVE'],
#      [41, 51, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['It’s like on off\r', {'entities': [[5, 16, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["When I'm down, I'm completely drained.\r",
#    {'entities': [[19, 37, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["It's hard to explain.\r",
#    {'entities': [[5, 20, 'BIPOLARDISORDER_POSITIVE']]}],
#   ['Hyperactive and restless.\r',
#    {'entities': [[0, 11, 'BIPOLARDISORDER_POSITIVE'],
#      [16, 24, 'BIPOLARDISORDER_POSITIVE']]}],
#   ["I'm so tired.\r", {'entities': [[0, 12, 'BIPOLARDISORDER_POSITIVE']]}],
# ...
#   ['I have uncontrollable urges to eat large amounts of food.\r',
#    {'entities': [[7, 27, 'STRESS_POSITIVE'], [31, 56, 'STRESS_POSITIVE']]}],
#   ["I'm trying to fill an emotional void.\r",
#    {'entities': [[22, 36, 'STRESS_POSITIVE']]}],
#   ['I feel guilty about my eating habits.\r',
#    {'entities': [[2, 36, 'STRESS_POSITIVE']]}],
#   ["I can't stop myself.\r", {'entities': [[2, 12, 'STRESS_POSITIVE']]}],
#   ["I haven't paid attention to my eating habits.\r",
#    {'entities': [[2, 44, 'STRESS_POSITIVE']]}],
#   ['I’m not considering about my meals.\r',
#    {'entities': [[4, 19, 'STRESS_POSITIVE']]}],
#   ["Yes, I can't unwind or can’t relax, even when I try to take a break.\r",
#    {'entities': [[7, 19, 'STRESS_POSITIVE'],
#      [23, 34, 'STRESS_POSITIVE'],
#      [48, 67, 'STRESS_POSITIVE']]}],
#   ['I struggle to relax because my mind is always racing with things I need to do.\r',
#    {'entities': [[2, 19, 'STRESS_POSITIVE'], [39, 64, 'STRESS_POSITIVE']]}],
#   ['It feels like my brain is in overdrive.\r',
#    {'entities': [[29, 38, 'STRESS_POSITIVE']]}],
#   ["Even when I'm alone, my mind is racing with worries and to-do lists.\r",
#    {'entities': [[24, 67, 'STRESS_POSITIVE']]}],
#   ['I try to meditate or try to read a book, but my thoughts keep pulling me back to work or whatever is stressing me out.\r',
#    {'entities': [[2, 17, 'STRESS_POSITIVE'],
#      [21, 39, 'STRESS_POSITIVE'],
#      [62, 77, 'STRESS_POSITIVE'],
#      [101, 117, 'STRESS_POSITIVE']]}],
#   ["It's like my body is physically tense, even when I'm trying to rest.\r",
#    {'entities': [[21, 37, 'STRESS_POSITIVE'], [53, 67, 'STRESS_POSITIVE']]}],
#   ['I feel like pressure about to explode.\r',
#    {'entities': [[12, 20, 'STRESS_POSITIVE'], [30, 37, 'STRESS_POSITIVE']]}],
#   ["My mind never stops racing, even when I'm trying to relax.\r",
#    {'entities': [[8, 26, 'STRESS_POSITIVE'], [42, 57, 'STRESS_POSITIVE']]}],
#   ["There's a list to do playing on repeat.\r",
#    {'entities': [[10, 20, 'STRESS_POSITIVE'], [32, 38, 'STRESS_POSITIVE']]}],
#   ['The tension in my body.\r', {'entities': [[4, 22, 'STRESS_POSITIVE']]}],
#   ["It's hard to let go.\r", {'entities': [[5, 19, 'STRESS_POSITIVE']]}],
#   ['Feel guilty for relaxing.\r', {'entities': [[0, 24, 'STRESS_POSITIVE']]}],
#   ["Can't quiet my mind.\r", {'entities': [[0, 11, 'STRESS_POSITIVE']]}],
#   ['I wake up feeling exhausted and feeling stressed.\r',
#    {'entities': [[32, 48, 'STRESS_POSITIVE']]}],
#   ['I like to be alone.\r', {'entities': [[10, 18, 'STRESS_POSITIVE']]}],
#   ['Short breaks feel like a lot.\r',
#    {'entities': [[6, 28, 'STRESS_POSITIVE']]}],
#   ['Yes, I find myself getting irritated easily.\r',
#    {'entities': [[19, 36, 'STRESS_POSITIVE']]}],
#   ['I’m feeling more anxious than I usually do.\r',
#    {'entities': [[12, 24, 'STRESS_POSITIVE']]}],
#   ['I’ve been feeling emotionally unstable.\r',
#    {'entities': [[18, 38, 'STRESS_POSITIVE']]}],
#   ["I’m having mood swings that can't control.\r",
#    {'entities': [[11, 41, 'STRESS_POSITIVE']]}],
#   ["That's putting mildly.\r", {'entities': [[7, 21, 'STRESS_POSITIVE']]}],
#   ["I'm on edge all the time.\r", {'entities': [[0, 11, 'STRESS_POSITIVE']]}],
#   ['Everything annoy me, and I snap at people for no reason.\r',
#    {'entities': [[11, 19, 'STRESS_POSITIVE'], [27, 41, 'STRESS_POSITIVE']]}],
#   ["My mind is racing with worries, and I can't shake this feeling of dread.\r",
#    {'entities': [[38, 71, 'STRESS_POSITIVE']]}],
#   ["I'm calm, and the next, I'm bursting into tears.\r",
#    {'entities': [[28, 36, 'STRESS_POSITIVE'], [42, 47, 'STRESS_POSITIVE']]}],
#   ["I don't recognize myself anymore.\r",
#    {'entities': [[2, 24, 'STRESS_POSITIVE']]}],
#   ["I'm living on a rollercoaster, and I can't get off.\r",
#    {'entities': [[4, 29, 'STRESS_POSITIVE'], [37, 50, 'STRESS_POSITIVE']]}],
#   ["I feel like I'm on edge all the time, and even small things set me off.\r",
#    {'entities': [[47, 70, 'STRESS_POSITIVE']]}],
#   ['Worried about everything.\r', {'entities': [[0, 24, 'STRESS_POSITIVE']]}],
#   ['My mind with negative thoughts.\r',
#    {'entities': [[0, 30, 'STRESS_POSITIVE']]}],
#   ['Can’t to be relax.\r', {'entities': [[0, 18, 'STRESS_POSITIVE']]}],
#   ["Put people away because I'm on edge.\r",
#    {'entities': [[0, 15, 'STRESS_POSITIVE']]}],
#   ["It's hard to focus.\r", {'entities': [[5, 18, 'STRESS_POSITIVE']]}],
#   ["I can't stay on one task.\r", {'entities': [[2, 24, 'STRESS_POSITIVE']]}],
#   ['\r', {'entities': []}],
#   ["Yes, I can't stop thinking about using the substance even when I'm trying to focus on work or other activities.\r",
#    {'entities': [[7, 26, 'ADDICTION_POSITIVE']]}],
#   ['I crave the substance.\r', {'entities': [[2, 7, 'ADDICTION_POSITIVE']]}],
#   ['It distracts me from other important things in my life.(Put me away from)\r',
#    {'entities': [[3, 15, 'ADDICTION_POSITIVE'],
#      [56, 72, 'ADDICTION_POSITIVE']]}],
#   ["It's like a battle in my head.\r",
#    {'entities': [[12, 30, 'ADDICTION_POSITIVE']]}],
#   ["I can't stop thinking about it, no matter how hard I try.\r",
#    {'entities': [[32, 56, 'ADDICTION_POSITIVE']]}],
#   ["It's always there, lurking in the background, waiting for the right moment to pounce.\r",
#    {'entities': [[19, 26, 'ADDICTION_POSITIVE'],
#      [46, 74, 'ADDICTION_POSITIVE']]}],
#   ["When I'm busy or doing something, I enjoy, that craving creeps back in.\r",
#    {'entities': [[48, 55, 'ADDICTION_POSITIVE'],
#      [63, 70, 'ADDICTION_POSITIVE']]}],
#   ["It's like an itch I can't scratch, and it drive me crazy.\r",
#    {'entities': [[20, 33, 'ADDICTION_POSITIVE'],
#      [42, 56, 'ADDICTION_POSITIVE']]}],
#   ["I've tried everything to distract myself, but nothing really works.\r",
#    {'entities': [[0, 67, 'ADDICTION_POSITIVE']]}],
#   ["It's a prison of my own mind.\r",
#    {'entities': [[7, 13, 'ADDICTION_POSITIVE']]}],
#   ['I think about it a lot.\r', {'entities': [[2, 16, 'ADDICTION_POSITIVE']]}],
#   ["I can't concentrate at work or be present with my family.\r",
#    {'entities': [[2, 27, 'ADDICTION_POSITIVE']]}],
#   ["I've tried to stop countless times, but it is too strong.\r",
#    {'entities': [[0, 18, 'ADDICTION_POSITIVE'],
#      [40, 56, 'ADDICTION_POSITIVE']]}],
#   ["I know it's harmful, but I can't stop myself.\r",
#    {'entities': [[7, 19, 'ADDICTION_POSITIVE'],
#      [27, 44, 'ADDICTION_POSITIVE']]}],
#   ['I have no control.\r', {'entities': [[0, 17, 'ADDICTION_POSITIVE']]}],
#   ["I want to stop / need to stop, but I don't know how.\r",
#    {'entities': [[2, 14, 'ADDICTION_POSITIVE'],
#      [17, 29, 'ADDICTION_POSITIVE'],
#      [37, 51, 'ADDICTION_POSITIVE']]}],
#   ['It controls me.\r', {'entities': [[0, 14, 'ADDICTION_POSITIVE']]}],
#   ['Yes, my substance use has caused problems at work and has strained my relationships with family and friends.\r',
#    {'entities': [[26, 41, 'ADDICTION_POSITIVE'],
#      [58, 83, 'ADDICTION_POSITIVE']]}],
#   ["I've had health issues and lost job because of my addiction, and it's also affected my relationships.\r",
#    {'entities': [[9, 22, 'ADDICTION_POSITIVE'],
#      [27, 31, 'ADDICTION_POSITIVE'],
#      [75, 83, 'ADDICTION_POSITIVE']]}],
#   ["I couldn't focus\r", {'entities': [[0, 16, 'ADDICTION_POSITIVE']]}],
#   ['I was always late\r', {'entities': [[6, 17, 'ADDICTION_POSITIVE']]}],
#   ['I got fired\r', {'entities': [[2, 11, 'ADDICTION_POSITIVE']]}],
#   ['A total disaster.\r', {'entities': [[8, 16, 'ADDICTION_POSITIVE']]}],
#   ['My family and friends are gone.\r',
#    {'entities': [[0, 30, 'ADDICTION_POSITIVE']]}],
#   ["They're tired of my lies and broken promises.\r",
#    {'entities': [[29, 44, 'ADDICTION_POSITIVE']]}],
#   ["I'm a mess.\r", {'entities': [[0, 10, 'ADDICTION_POSITIVE']]}],
#   ["I've got physical problems, I'm always sick,\r",
#    {'entities': [[5, 26, 'ADDICTION_POSITIVE'],
#      [32, 43, 'ADDICTION_POSITIVE']]}],
#   ["I don't recognize myself anymore.\r",
#    {'entities': [[2, 32, 'ADDICTION_POSITIVE']]}],
#   ["I've destroyed everything important in my life.\r",
#    {'entities': [[5, 25, 'ADDICTION_POSITIVE']]}],
#   ["I'm living a nightmare.\r",
#    {'entities': [[13, 22, 'ADDICTION_POSITIVE']]}],
#   ["I've lost works because of it.\r",
#    {'entities': [[5, 26, 'ADDICTION_POSITIVE']]}],
#   ["I've spent money on drugs and alcohol.\r",
#    {'entities': [[20, 25, 'ADDICTION_POSITIVE'],
#      [30, 37, 'ADDICTION_POSITIVE']]}],
#   ['I’ve sickness.\r', {'entities': [[5, 13, 'ADDICTION_POSITIVE']]}],
#   ["I've tried to quit.\r", {'entities': [[5, 18, 'ADDICTION_POSITIVE']]}],
#   ['Withdrawal symptoms are unbearable.\r',
#    {'entities': [[0, 19, 'ADDICTION_POSITIVE'],
#      [24, 34, 'ADDICTION_POSITIVE']]}],
#   ['It has destroyed my relationships.\r',
#    {'entities': [[7, 33, 'ADDICTION_POSITIVE']]}],
#   ["I've pushed away everyone who cares about me.\r",
#    {'entities': [[5, 25, 'ADDICTION_POSITIVE']]}],
#   ['Afraid of what people will think of me.\r',
#    {'entities': [[0, 38, 'ADDICTION_POSITIVE']]}],
#   ["I don't know how to rebuild my life.\r",
#    {'entities': [[0, 12, 'ADDICTION_POSITIVE'],
#      [20, 35, 'ADDICTION_POSITIVE']]}],
#   ['Yes, I find that I need to use more of the substance to get the same high or feeling that I used to get with less.\r',
#    {'entities': [[19, 35, 'ADDICTION_POSITIVE'],
#      [56, 73, 'ADDICTION_POSITIVE'],
#      [77, 103, 'ADDICTION_POSITIVE']]}],
#   ['I’ve noticed that I need to engage in the behavior more frequently or intensely to feel the same level of satisfaction.\r',
#    {'entities': [[20, 34, 'ADDICTION_POSITIVE'],
#      [51, 66, 'ADDICTION_POSITIVE'],
#      [70, 79, 'ADDICTION_POSITIVE'],
#      [83, 96, 'ADDICTION_POSITIVE']]}],
#   ['It used to be one drink, one line, or one hit would do it.\r',
#    {'entities': [[14, 23, 'ADDICTION_POSITIVE'],
#      [25, 33, 'ADDICTION_POSITIVE'],
#      [38, 45, 'ADDICTION_POSITIVE']]}],
#   ['I need double, triple, even more to feel anything.\r',
#    {'entities': [[7, 13, 'ADDICTION_POSITIVE'],
#      [15, 21, 'ADDICTION_POSITIVE'],
#      [28, 40, 'ADDICTION_POSITIVE']]}],
#   ["It's like my body is building up tolerance.\r",
#    {'entities': [[21, 42, 'ADDICTION_POSITIVE']]}],
#   ['I need more and more to get the same high.\r',
#    {'entities': [[2, 11, 'ADDICTION_POSITIVE']]}],
#   ["It's never end.\r", {'entities': [[5, 14, 'ADDICTION_POSITIVE']]}],
#   ['I used to be able to control it, but now it controls me.(Unable to control)\r',
#    {'entities': [[13, 28, 'ADDICTION_POSITIVE'],
#      [41, 56, 'ADDICTION_POSITIVE'],
#      [57, 74, 'ADDICTION_POSITIVE']]}],
#   ["I feel like I'm chasing a ghost.\r",
#    {'entities': [[16, 23, 'ADDICTION_POSITIVE']]}],
#   ['I’m trying to recapture that first amazing feeling.\r',
#    {'entities': [[14, 23, 'ADDICTION_POSITIVE'],
#      [35, 50, 'ADDICTION_POSITIVE']]}],
#   ["It's always just out of reach.\r",
#    {'entities': [[17, 29, 'ADDICTION_POSITIVE']]}],
#   ['I have to keep increasing the amount to feel the same way.\r',
#    {'entities': [[15, 25, 'ADDICTION_POSITIVE'],
#      [40, 57, 'ADDICTION_POSITIVE']]}],
#   ["I can't stop myself from using more.\r",
#    {'entities': [[2, 19, 'ADDICTION_POSITIVE'],
#      [25, 35, 'ADDICTION_POSITIVE']]}],
#   ["I'm spending way too much.(Spend too much)\r",
#    {'entities': [[4, 12, 'ADDICTION_POSITIVE'],
#      [27, 41, 'ADDICTION_POSITIVE']]}],
#   ["I can't stop myself.\r", {'entities': [[0, 19, 'ADDICTION_POSITIVE']]}],
#   ["I feel physically sick if I don't use it.\r",
#    {'entities': [[18, 40, 'ADDICTION_POSITIVE']]}],
#   ["I don't think I use it that much.\r",
#    {'entities': [[2, 13, 'ADDICTION_POSITIVE'],
#      [23, 32, 'ADDICTION_POSITIVE']]}],
#   ['I just enjoy it.\r', {'entities': [[2, 12, 'ADDICTION_POSITIVE']]}],
#   ['Yes, I’ve tried to quit several times, but I always end up going back to it.\r',
#    {'entities': [[24, 37, 'ADDICTION_POSITIVE'],
#      [52, 75, 'ADDICTION_POSITIVE']]}],
#   ["I’ve made attempts to cut down, but I can't stop or reduce my use on my own.\r",
#    {'entities': [[10, 18, 'ADDICTION_POSITIVE'],
#      [22, 30, 'ADDICTION_POSITIVE'],
#      [44, 48, 'ADDICTION_POSITIVE'],
#      [52, 58, 'ADDICTION_POSITIVE'],
#      [62, 75, 'ADDICTION_POSITIVE']]}],
#   ["I've tried so many times.\r",
#    {'entities': [[11, 24, 'ADDICTION_POSITIVE']]}],
#   ['Every time I promise myself to stop, I end up right back where I started.\r',
#    {'entities': [[0, 10, 'ADDICTION_POSITIVE'],
#      [63, 72, 'ADDICTION_POSITIVE']]}],
#   ["It's like a part of me is stronger than my willpower.\r",
#    {'entities': [[12, 22, 'ADDICTION_POSITIVE'],
#      [26, 39, 'ADDICTION_POSITIVE'],
#      [43, 52, 'ADDICTION_POSITIVE']]}],
#   ['Nothing works.\r', {'entities': [[0, 13, 'ADDICTION_POSITIVE']]}],
#   ['Cutting back slowly.\r',
#    {'entities': [[0, 7, 'ADDICTION_POSITIVE'],
#      [13, 19, 'ADDICTION_POSITIVE']]}],
#   ['The cravings are too strong.\r',
#    {'entities': [[4, 27, 'ADDICTION_POSITIVE']]}],
#   ["It's like I'm trapped.\r", {'entities': [[14, 21, 'ADDICTION_POSITIVE']]}],
#   ['Never-ending cycle.\r', {'entities': [[0, 12, 'ADDICTION_POSITIVE']]}],
#   ["I've tried to quit many times.\r",
#    {'entities': [[5, 18, 'ADDICTION_POSITIVE']]}],
#   ['I always end up going back. (always end up)\r',
#    {'entities': [[9, 27, 'ADDICTION_POSITIVE'],
#      [29, 42, 'ADDICTION_POSITIVE']]}],
#   ['I have no control.\r', {'entities': [[0, 17, 'ADDICTION_POSITIVE']]}],
#   ['Withdrawal symptoms were unbearable.\r',
#    {'entities': [[0, 19, 'ADDICTION_POSITIVE'],
#      [25, 35, 'ADDICTION_POSITIVE']]}],
#   ['It’s a battle.\r', {'entities': [[0, 13, 'ADDICTION_POSITIVE']]}],
#   ["I don't believe in myself.\r",
#    {'entities': [[2, 15, 'ADDICTION_POSITIVE']]}],
#   ['I always give in.\r', {'entities': [[9, 17, 'ADDICTION_POSITIVE']]}],
#   ["I haven't tried to quit.\r",
#    {'entities': [[2, 15, 'ADDICTION_POSITIVE']]}],
#   ["It's hard to talk about.\r",
#    {'entities': [[5, 17, 'ADDICTION_POSITIVE']]}],
#   ['Yes, I spend a lot of my time getting the substance, using it.\r',
#    {'entities': [[7, 21, 'ADDICTION_POSITIVE']]}],
#   ['Recovering from its effects.\r',
#    {'entities': [[0, 10, 'ADDICTION_POSITIVE'],
#      [20, 27, 'ADDICTION_POSITIVE']]}],
#   ['Most of my day is taken up by the behavior, including finding time to engage in it and dealing with the aftermath.\r',
#    {'entities': [[18, 26, 'ADDICTION_POSITIVE'],
#      [70, 76, 'ADDICTION_POSITIVE'],
#      [87, 99, 'ADDICTION_POSITIVE']]}],
#   ["That's an understatement.\r",
#    {'entities': [[10, 24, 'ADDICTION_POSITIVE']]}],
#   ['My life revolves around it.\r',
#    {'entities': [[3, 23, 'ADDICTION_POSITIVE']]}],
#   ["It's like a black hole sucking me in.\r",
#    {'entities': [[23, 36, 'ADDICTION_POSITIVE']]}],
#   ['I spend hours each day figuring out how to get more, where to get it, and how much I can afford.\r',
#    {'entities': [[2, 13, 'ADDICTION_POSITIVE'],
#      [23, 46, 'ADDICTION_POSITIVE'],
#      [53, 68, 'ADDICTION_POSITIVE'],
#      [74, 82, 'ADDICTION_POSITIVE'],
#      [89, 95, 'ADDICTION_POSITIVE']]}],
#   ["There's the time spent using it or recovering from the crash.\r",
#    {'entities': [[12, 22, 'ADDICTION_POSITIVE'],
#      [35, 45, 'ADDICTION_POSITIVE']]}],
#   ["It's taken over my life.\r",
#    {'entities': [[5, 15, 'ADDICTION_POSITIVE']]}],
#   ["I'm a prisoner to this addiction.\r",
#    {'entities': [[23, 32, 'ADDICTION_POSITIVE']]}],
#   ['I’m addicted to this.\r', {'entities': [[0, 12, 'ADDICTION_POSITIVE']]}],
#   ['Everything fallen by the wayside.\r',
#    {'entities': [[0, 17, 'ADDICTION_POSITIVE']]}],
#   ['My life revolves around it.\r',
#    {'entities': [[3, 23, 'ADDICTION_POSITIVE']]}],
#   ["I've neglected everything else in my life.\r",
#    {'entities': [[5, 14, 'ADDICTION_POSITIVE']]}],
#   ['I spend most of my time.\r',
#    {'entities': [[2, 23, 'ADDICTION_POSITIVE']]}],
#   ["I can't manage my time anymore.\r",
#    {'entities': [[2, 14, 'ADDICTION_POSITIVE'],
#      [23, 30, 'ADDICTION_POSITIVE']]}],
#   ['I like that and need it again and again.\r',
#    {'entities': [[16, 29, 'ADDICTION_POSITIVE']]}],
#   ["I don't know how much time I spend on it.\r",
#    {'entities': [[13, 26, 'ADDICTION_POSITIVE'],
#      [29, 37, 'ADDICTION_POSITIVE']]}],
#   ['I spend time on it.\r', {'entities': [[0, 18, 'ADDICTION_POSITIVE']]}],
#   ['\r', {'entities': []}]]}

# %%
# for text, annot in tqdm(TRAIN_DATA['annotations']):
#   doc = nlp.make_doc(text)
#   ents = []
#   for start, end, label in annot["entities"]:
#     span = doc.char_span(start, end, label=label, alignment_mode="contract")
#     if span is None:
#       print("Skipping entity")
#     else:
#       ents.append(span)
#   doc.ents = ents
#   db.add(doc)

#   db.to_disk("/content/drive/MyDrive/aromatic/updated/training_data.spacy")

from tqdm import tqdm

for item in tqdm(TRAIN_DATA['annotations']):
    if item is None:
        print("Skipping None item in annotations")
        continue

    if not isinstance(item, (tuple, list)) or len(item) != 2:
        print(f"Skipping incorrectly formatted item: {item}")
        continue

    text, annot = item
    doc = nlp.make_doc(text)
    ents = []

    for start, end, label in annot.get("entities", []):
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print(f"Skipping entity in text: {text}")
        else:
            ents.append(span)

    doc.ents = ents
    db.add(doc)

db.to_disk("/content/drive/MyDrive/aromatic/updated/training_data.spacy")
# Out:
# 100%|██████████| 631/631 [00:00<00:00, 3191.36it/s]
# Skipping None item in annotations
# Skipping None item in annotations
# Skipping None item in annotations
# Skipping None item in annotations
# Skipping None item in annotations

# %%
! python -m spacy init config "/content/drive/MyDrive/aromatic/updated/config.cfg" --lang en --pipeline ner --optimize efficiency
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/drive/MyDrive/aromatic/updated/config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train "/content/drive/MyDrive/aromatic/updated/config.cfg" --output ./ --paths.train="/content/drive/MyDrive/aromatic/updated/training_data.spacy" --paths.dev="/content/drive/MyDrive/aromatic/updated/training_data.spacy"
# Out:
# ℹ Saving to output directory: .
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     55.77    0.00    0.00    0.00    0.00
#   2     200        253.17   4486.57    4.83   11.49    3.06    0.05
#   5     400        697.34   4549.40   23.04   27.56   19.80    0.23
#   8     600       1818.17   5494.82   42.39   45.35   39.80    0.42
#  12     800       3251.05   6040.10   61.21   65.24   57.65    0.61
#  18    1000       4644.89   5788.56   69.61   70.04   69.18    0.70
#  24    1200       6281.57   5978.05   77.92   80.15   75.82    0.78
#  32    1400       6495.43   5818.06   84.40   84.32   84.49    0.84
#  42    1600       9112.93   6380.54   85.47   85.12   85.82    0.85
#  53    1800       9918.55   6100.87   87.67   87.58   87.76    0.88
#  68    2000      10099.89   6108.53   90.82   90.82   90.82    0.91
#  85    2200      10275.04   6095.14   92.66   93.19   92.14    0.93
# 106    2400      10407.11   5655.99   94.96   95.65   94.29    0.95
# 129    2600       9071.48   4917.34   95.33   95.97   94.69    0.95
# 151    2800       7983.00   4384.75   95.66   95.80   95.51    0.96
# 173    3000       6536.50   3879.94   96.77   97.22   96.33    0.97
# 195    3200       6113.76   3572.14   97.14   97.24   97.04    0.97
# 218    3400       5181.62   3057.49   97.09   97.24   96.94    0.97
# 240    3600       4683.47   2868.35   97.19   97.34   97.04    0.97
# 262    3800       3912.80   2533.75   98.11   98.46   97.76    0.98
# 284    4000       3249.64   2051.03   98.11   98.26   97.96    0.98
# 306    4200       2574.19   1906.03   98.06   97.96   98.16    0.98
# 329    4400       2589.28   1861.79   97.82   97.28   98.37    0.98
# 351    4600       2161.47   1690.03   98.06   98.26   97.86    0.98
# 373    4800       2446.13   1715.12   98.11   98.36   97.86    0.98
# 395    5000       1782.17   1608.55   98.11   98.36   97.86    0.98
# 418    5200       1880.05   1580.73   98.42   98.57   98.27    0.98
# 440    5400       1644.55   1652.45   98.62   98.77   98.47    0.99
# 462    5600       1659.75   1408.50   98.62   98.67   98.57    0.99
# 484    5800       1921.62   1421.57   98.52   98.87   98.16    0.99
# 506    6000       1486.88   1418.51   98.72   99.18   98.27    0.99
# 529    6200       1717.13   1360.70   98.72   98.97   98.47    0.99
# 551    6400       1358.36   1300.75   98.72   99.18   98.27    0.99
# 573    6600       1324.62   1133.32   98.73   98.67   98.78    0.99
# 595    6800       1125.66   1181.61   98.42   98.47   98.37    0.98
# 618    7000       2052.20   1339.50   98.42   98.27   98.57    0.98
# 640    7200       1409.80   1157.52   98.72   99.18   98.27    0.99
# 662    7400       2588.00   1291.76   98.72   98.77   98.67    0.99
# 684    7600       1037.04   1090.07   98.72   98.97   98.47    0.99
# 706    7800       1325.44   1066.18   98.72   99.08   98.37    0.99
# 729    8000        973.88    931.28   98.82   98.98   98.67    0.99
# 751    8200        900.58    957.65   98.72   98.87   98.57    0.99
# 773    8400        856.78    895.08   98.82   98.98   98.67    0.99
# 795    8600        647.40    802.51   98.93   99.18   98.67    0.99
# 818    8800       1269.97    827.08   98.83   98.78   98.88    0.99
# 840    9000        666.19    764.80   98.67   98.67   98.67    0.99
# 862    9200        613.52    781.33   98.82   99.08   98.57    0.99
# 884    9400        644.65    760.13   98.93   99.08   98.78    0.99
# 906    9600        841.29    815.17   98.93   99.08   98.78    0.99
# 929    9800        473.07    742.48   98.93   99.18   98.67    0.99
# 951   10000        673.44    753.36   98.92   99.38   98.47    0.99
# 973   10200        512.75    746.05   98.92   99.38   98.47    0.99
# 995   10400       1378.20    784.97   98.67   98.57   98.78    0.99
# 1018   10600        681.72    812.05   98.82   99.18   98.47    0.99
# 1040   10800        547.30    750.53   98.83   98.78   98.88    0.99
# 1062   11000        503.79    744.87   98.93   99.08   98.78    0.99
# ✔ Saved pipeline to output directory
# model-last

# %%
import shutil
import zipfile
import os

# Source folder path to be zipped
source_folder_path = '/content/model-last'

#/content/drive/MyDrive/Colab Notebooks/smartDiary/
# Destination zip file path
destination_zip_path = '/content/drive/MyDrive/aromatic/updated/model-last.zip'

# Zip the source folder
def zip_folder(folder_path, output_path):
    with zipfile.ZipFile(output_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, folder_path))

# Zip the folder
zip_folder(source_folder_path, destination_zip_path)

# Verify if the zip file has been created successfully
if os.path.exists(destination_zip_path):
    print(f'The folder has been successfully zipped and saved to: {destination_zip_path}')
else:
    print('Failed to zip the folder.')
# Out:
# The folder has been successfully zipped and saved to: /content/drive/MyDrive/aromatic/updated/model-last.zip

# %%
# Source folder path to be zipped
source_folder_path = '/content/model-best'

# Destination zip file path
destination_zip_path = '/content/drive/MyDrive/aromatic/updated/model-best.zip'

# Zip the source folder
def zip_folder(folder_path, output_path):
    with zipfile.ZipFile(output_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, folder_path))

# Zip the folder
zip_folder(source_folder_path, destination_zip_path)

# Verify if the zip file has been created successfully
if os.path.exists(destination_zip_path):
    print(f'The folder has been successfully zipped and saved to: {destination_zip_path}')
else:
    print('Failed to zip the folder.')
# Out:
# The folder has been successfully zipped and saved to: /content/drive/MyDrive/aromatic/updated/model-best.zip

# %%
nlp_ner = spacy.load("/content/model-best")

# %%
doc = nlp_ner(''' Yes, I've been feeling constantly nervous and worried about a lot of things, even Worry about small issues''')

# %%
spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Yes, I've been feeling
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     constantly nervous and worried
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANXIETY_POSITIVE</span>
# </mark>
#  about a lot of things, even
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Worry about small issues
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANXIETY_POSITIVE</span>
# </mark>
# </div></span>

# %%
import zipfile
import os

def zip_folder(folder_path, output_path):
    with zipfile.ZipFile(output_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, folder_path))

# Specify the folder path and output path
folder_path = '/content/drive/MyDrive/aromatic/updated/'  # Replace with your folder path
output_path = '/content/drive/MyDrive/aromatic/updated.zip'  # Replace with your desired output path

# Zip the folder
zip_folder(folder_path, output_path)
